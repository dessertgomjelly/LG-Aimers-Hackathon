# %% [markdown]
# # 영업 성공 여부 분류 경진대회

# %% [markdown]
# ## 1. 데이터 확인

# %% [markdown]
# ### 필수 라이브러리

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### 데이터 셋 읽어오기

# %%
df_train = pd.read_csv("train.csv") # 학습용 데이터
df_test = pd.read_csv("submission.csv") # 테스트 데이터(제출파일의 데이터)

# %%
df_train
# Out:
#        bant_submit          customer_country business_unit  \
# 0             1.00  /Quezon City/Philippines            AS
# 1             1.00        /PH-00/Philippines            AS
# 2             1.00           /Kolkata /India            AS
# 3             1.00        /Bhubaneswar/India            AS
# 4             1.00          /Hyderabad/India            AS
# ...            ...                       ...           ...
# 59294         1.00           /Sląskie/Poland            AS
# 59295         0.75      /Bogotá DC /Colombia            AS
# 59296         0.75               /Pisco/Peru            AS
# 59297         1.00  /santa cruz bolivia/Peru            AS
# 59298         0.75             /paris/France      Solution
#
#        com_reg_ver_win_rate  customer_idx          customer_type  enterprise  \
# 0                  0.066667         32160           End-Customer  Enterprise
# 1                  0.066667         23122           End-Customer  Enterprise
# 2                  0.088889          1755           End-Customer  Enterprise
# 3                  0.088889          4919           End-Customer  Enterprise
# 4                  0.088889         17126  Specifier/ Influencer  Enterprise
# ...                     ...           ...                    ...         ...
# 59294                   NaN         33747           End Customer         SMB
# 59295              0.040000         35420  Specifier/ Influencer  Enterprise
# 59296              0.040000         19249  Specifier/ Influencer  Enterprise
# 59297              0.040000         40327                    NaN  Enterprise
# 59298                   NaN         30268                    NaN  Enterprise
#
#        historical_existing_cnt  id_strategic_ver  it_strategic_ver  ...  \
# 0                          NaN               NaN               NaN  ...
# 1                         12.0               NaN               NaN  ...
# 2                        144.0               NaN               NaN  ...
# 3                          NaN               NaN               NaN  ...
# 4                          NaN               NaN               NaN  ...
# ...                        ...               ...               ...  ...
# 59294                      NaN               NaN               NaN  ...
# 59295                      NaN               NaN               NaN  ...
# 59296                      NaN               NaN               NaN  ...
# 59297                      NaN               NaN               NaN  ...
# 59298                      NaN               NaN               NaN  ...
#
#        response_corporate    expected_timeline  ver_cus ver_pro  \
# 0                   LGEPH   less than 3 months        1       0
# 1                   LGEPH   less than 3 months        1       0
# 2                   LGEIL   less than 3 months        1       0
# 3                   LGEIL   less than 3 months        1       0
# 4                   LGEIL   less than 3 months        0       0
# ...                   ...                  ...      ...     ...
# 59294               LGEPL  3 months ~ 6 months        0       0
# 59295               LGECB    9 months ~ 1 year        0       0
# 59296               LGEPR   less than 3 months        0       0
# 59297               LGEPR     more than a year        0       0
# 59298               LGEKR   less than 3 months        0       0
#
#       ver_win_rate_x ver_win_ratio_per_bu       business_area  \
# 0           0.003079             0.026846  corporate / office
# 1           0.003079             0.026846  corporate / office
# 2           0.003079             0.026846  corporate / office
# 3           0.003079             0.026846  corporate / office
# 4           0.003079             0.026846  corporate / office
# ...              ...                  ...                 ...
# 59294       0.000026             0.028777     public facility
# 59295       0.000026             0.028777     public facility
# 59296       0.000026             0.028777     public facility
# 59297       0.000026             0.028777     public facility
# 59298       0.000026                  NaN     public facility
#
#       business_subarea lead_owner is_converted
# 0          Engineering          0         True
# 1          Advertising          1         True
# 2         Construction          2         True
# 3          IT/Software          3         True
# 4                  NaN          4         True
# ...                ...        ...          ...
# 59294           Others        694        False
# 59295              NaN         39        False
# 59296              NaN        125        False
# 59297              NaN        134        False
# 59298              NaN        441        False
#
# [59299 rows x 29 columns]

# %% [markdown]
# # expected_timeline - 4 + business관련 결측치 처리

# %% [markdown]
# expected_timeline : 고객의 요청한 처리 일정
#
# 1. 처리 날짜 : 0 ~ 3m 0 ~ 6m ...
#
# 2. 처리 상태 : requirement, response ...
#
# 3.
# 4. 리드의 상태 기준 (Lead Status):
# 5. 기타 기준:

# %%
# 'expected_timeline' 열에서 값이 없는지 확인
df_train['expected_timeline'].isnull().sum()
# Out:
# 30863

# %%
from collections import Counter
from nltk.tokenize import word_tokenize
import nltk

nltk.download('punkt')

# 'expected_timeline' 열에서 값이 있는 행만 선택
df_valid_rows = df_train.dropna(subset=['expected_timeline'])

# 'expected_timeline' 열의 값을 모두 가져와서 텍스트로 결합
text_data = ' '.join(df_valid_rows['expected_timeline'].astype(str))

# 토큰화 (단어 분리)
tokens = word_tokenize(text_data)

# 단어 빈도수 계산
word_freq = Counter(tokens)

word_freq
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/dessert_gomjelly/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Counter({'months': 30725,
#          '3': 22288,
#          'than': 20390,
#          'less': 17366,
#          '~': 7225,
#          '6': 6235,
#          'year': 4125,
#          'a': 3035,
#          'more': 3027,
#          '9': 2200,
#          '1': 1107,
#          '.': 511,
#          'to': 186,
#          'the': 166,
#          ',': 146,
#          'client': 145,
#          'with': 136,
#          'not': 124,
#          'for': 122,
#          'is': 121,
#          'details': 117,
#          'up': 115,
#          'in': 114,
#          'followed': 98,
#          'being': 97,
#          'he': 95,
#          'etc': 95,
#          'shared': 85,
#          'requirement': 81,
#          'less_than_3_months': 76,
#          'of': 75,
#          'customer': 74,
#          'and': 74,
#          'demo': 65,
#          'hence': 64,
#          'will': 63,
#          'on': 62,
#          'system': 59,
#          'call': 57,
#          'no': 56,
#          'are': 54,
#          'idb': 50,
#          'mailed': 46,
#          'have': 43,
#          'any': 41,
#          'partner': 36,
#          'although': 36,
#          'they': 36,
#          'lead': 36,
#          'as': 34,
#          'having': 32,
#          'closig': 31,
#          'discussed': 31,
#          'already': 30,
#          'now': 30,
#          'budget': 30,
#          'rd': 29,
#          'quote': 28,
#          'but': 28,
#          'closing': 27,
#          'him': 27,
#          'we': 24,
#          'send': 24,
#          'back': 24,
#          'purchase': 23,
#          'update': 22,
#          'has': 21,
#          'was': 21,
#          'need': 21,
#          'looking': 21,
#          'want': 21,
#          'answering': 20,
#          'our': 20,
#          'inch': 19,
#          'asked': 19,
#          "n't": 18,
#          'touch': 18,
#          'i': 18,
#          'from': 17,
#          'tried': 17,
#          'after': 17,
#          'times': 16,
#          'next': 16,
#          'this': 16,
#          'only': 16,
#          'connect': 15,
#          'required': 15,
#          'price': 15,
#          'further': 15,
#          'product': 14,
#          'week': 14,
#          'under': 14,
#          'require': 13,
#          'buy': 13,
#          'responding': 13,
#          'mail': 12,
#          'forwarded': 12,
#          'prices': 12,
#          'response': 12,
#          '--': 11,
#          'be': 11,
#          'done': 11,
#          'low': 11,
#          'later': 11,
#          'drop': 11,
#          'through': 10,
#          'take': 10,
#          'meeting': 10,
#          'come': 10,
#          'quotation': 10,
#          'discussion': 10,
#          'dropping': 10,
#          'case': 10,
#          'did': 10,
#          'working': 10,
#          'display': 10,
#          'dont': 10,
#          'sent': 9,
#          'interested': 9,
#          'update-': 9,
#          'confirm': 9,
#          'could': 9,
#          'it': 9,
#          'issue': 9,
#          'his': 9,
#          'bdo': 9,
#          'duplicate': 9,
#          '3_months_~_6_months': 9,
#          'respond': 9,
#          'contact': 9,
#          'at': 9,
#          'progress': 9,
#          'again': 9,
#          'reach': 8,
#          'led': 8,
#          'there': 8,
#          'follow': 8,
#          'reachable': 8,
#          'check': 8,
#          'same': 8,
#          'if': 8,
#          '2022': 8,
#          'spoke': 8,
#          'available': 8,
#          'very': 8,
#          'plan': 8,
#          '2': 8,
#          'browsing': 8,
#          'purchased': 8,
#          'exploring': 7,
#          'inquiry': 7,
#          'signage': 7,
#          'team': 7,
#          'its': 7,
#          'existing': 7,
#          'share': 7,
#          'post': 7,
#          'once': 7,
#          'then': 7,
#          'dropped': 7,
#          'produt': 7,
#          'us': 7,
#          'model': 6,
#          'office': 6,
#          'following': 6,
#          'per': 6,
#          'due': 6,
#          'checking': 6,
#          'an': 6,
#          'made': 6,
#          '43': 6,
#          'tv': 6,
#          'discuss': 6,
#          'one': 6,
#          'calls': 6,
#          '65': 6,
#          'email': 6,
#          'month': 6,
#          'pune': 6,
#          'fu': 6,
#          'phone': 6,
#          'plans': 6,
#          'home': 6,
#          'local': 6,
#          '9_months_~_1_year': 6,
#          '–': 6,
#          'just': 5,
#          'aug': 5,
#          'days': 5,
#          'get': 5,
#          'wont': 5,
#          '&': 5,
#          '-': 5,
#          '4th': 5,
#          'multiple': 5,
#          'size': 5,
#          'rnr': 5,
#          'solution': 5,
#          'displays': 5,
#          'new': 5,
#          'also': 5,
#          'keep': 5,
#          'planned': 5,
#          'their': 5,
#          'may': 5,
#          'revert': 5,
#          'december': 5,
#          'number': 5,
#          'tomorrow': 5,
#          'had': 5,
#          'been': 4,
#          'some': 4,
#          '..': 4,
#          'video': 4,
#          'sept': 4,
#          'needs': 4,
#          'cross': 4,
#          'onequick': 4,
#          'planning': 4,
#          'first': 4,
#          'custome': 4,
#          "''": 4,
#          'shall': 4,
#          'decide': 4,
#          ':': 4,
#          'vc': 4,
#          'june': 4,
#          'busy': 4,
#          'interactive': 4,
#          'pricing': 4,
#          'budgets': 4,
#          'outdoor': 4,
#          '65tr3dj': 4,
#          '75tr3dj': 4,
#          '6_months_~_9_months': 4,
#          '49vl5g': 4,
#          'consumer': 4,
#          'called': 4,
#          'more_than_a_year': 4,
#          'opp': 4,
#          'or': 3,
#          'last': 3,
#          'discused': 3,
#          'detail': 3,
#          'digital': 3,
#          'so': 3,
#          'sharing': 3,
#          'aligned': 3,
#          'il220100042906': 3,
#          'repeat': 3,
#          'scheduled': 3,
#          'within': 3,
#          'lacs': 3,
#          '55': 3,
#          'aio': 3,
#          'evaluating': 3,
#          'procuring': 3,
#          'quoted': 3,
#          'use': 3,
#          'spoken': 3,
#          'quick': 3,
#          'unit': 3,
#          'expectation': 3,
#          'connecting': 3,
#          '86': 3,
#          'inches': 3,
#          'aggressive': 3,
#          '14th': 3,
#          'am': 3,
#          'management': 3,
#          'business': 3,
#          'trying': 3,
#          'november': 3,
#          'work': 3,
#          '5': 3,
#          'try': 3,
#          'ask': 3,
#          'lifted': 3,
#          'followup': 3,
#          'many': 3,
#          'person': 3,
#          'do': 3,
#          'panel': 3,
#          'yet': 3,
#          'off': 3,
#          'which': 3,
#          'brand': 3,
#          'were': 3,
#          'problem': 3,
#          'by': 3,
#          'enquiry': 3,
#          'customers': 3,
#          'several': 3,
#          'said': 3,
#          'going': 3,
#          '8th': 3,
#          'assigned': 3,
#          'intial': 3,
#          'convert': 3,
#          'complete': 3,
#          'info': 3,
#          'eol': 2,
#          'sales': 2,
#          'closure': 2,
#          'close': 2,
#          'july': 2,
#          'purchse': 2,
#          'inquiring': 2,
#          'given': 2,
#          'requires': 2,
#          'into': 2,
#          'ahead': 2,
#          'scope': 2,
#          'wall': 2,
#          'may-': 2,
#          'changed': 2,
#          'si': 2,
#          'feb': 2,
#          'comparing': 2,
#          'ongoing': 2,
#          'opportunity': 2,
#          'october': 2,
#          'action': 2,
#          'well': 2,
#          't': 2,
#          '(': 2,
#          ')': 2,
#          'two': 2,
#          'works': 2,
#          '27th': 2,
#          'mr': 2,
#          'communication': 2,
#          'aurangabad': 2,
#          'requested': 2,
#          'boq': 2,
#          'much': 2,
#          'oct': 2,
#          'tr3dj': 2,
#          'remarks': 2,
#          '75': 2,
#          'completed': 2,
#          'pending': 2,
#          'sku': 2,
#          'order': 2,
#          'taken': 2,
#          'aug-': 2,
#          'delhi': 2,
#          'consultant': 2,
#          '32': 2,
#          'physical': 2,
#          'room': 2,
#          'rajnikant': 2,
#          'thru': 2,
#          'whatsapp': 2,
#          '/': 2,
#          'visit': 2,
#          'see': 2,
#          'samsung': 2,
#          'gem': 2,
#          'procurement': 2,
#          'monday': 2,
#          'end': 2,
#          'received': 2,
#          'september': 2,
#          'requesting': 2,
#          'clarity': 2,
#          'restaurant': 2,
#          'forwarding': 2,
#          'active': 2,
#          'range': 2,
#          'cms': 2,
#          'reqired': 2,
#          'budgetory': 2,
#          'concern': 2,
#          'financial': 2,
#          'reasons': 2,
#          'lg': 2,
#          '50k': 2,
#          'needed': 2,
#          'connected': 2,
#          'camera': 2,
#          'looped': 2,
#          'process': 2,
#          'known': 2,
#          'cloudwalker': 2,
#          'couldnt': 2,
#          'even': 2,
#          'seen': 2,
#          'commercial': 2,
#          'switched': 2,
#          'walls': 2,
#          'rs': 2,
#          'vu': 2,
#          'bigger': 2,
#          'dot': 2,
#          'mobile': 2,
#          'partners': 2,
#          'recent': 2,
#          'channel': 2,
#          'currently': 2,
#          'couple': 2,
#          'wrong': 2,
#          'provided': 2,
#          'intrested': 2,
#          'evaluation': 2,
#          'them': 2,
#          'enough': 2,
#          'disti': 2,
#          'trade': 2,
#          'date': 2,
#          'wanted': 2,
#          'march': 2,
#          'small': 2,
#          '20': 2,
#          'project': 2,
#          'products': 2,
#          'picking': 2,
#          'requiremeent': 1,
#          'designated': 1,
#          'expected': 1,
#          'receing': 1,
#          'properly': 1,
#          'repeated': 1,
#          'confimred': 1,
#          'mulitple': 1,
#          'buying': 1,
#          '7th': 1,
#          'multipe': 1,
#          '7': 1,
#          'ankit': 1,
#          'dehli': 1,
#          'tender': 1,
#          'right': 1,
#          'static': 1,
#          'signages': 1,
#          'himself': 1,
#          'manufacturer': 1,
#          'initaited': 1,
#          'requirements': 1,
#          'budge': 1,
#          'yhe': 1,
#          'jayant': 1,
#          '13th': 1,
#          'spet': 1,
#          '15th': 1,
#          'orno': 1,
#          'information': 1,
#          '49': 1,
#          '50': 1,
#          'opprtunity': 1,
#          'scheduling': 1,
#          'went': 1,
#          'invalid': 1,
#          'jabra': 1,
#          'proposed': 1,
#          'contraint': 1,
#          'idea': 1,
#          'barc': 1,
#          'partner.its': 1,
#          'useful': 1,
#          'inquries.closing': 1,
#          'other': 1,
#          'brands': 1,
#          'don': 1,
#          '’': 1,
#          'that': 1,
#          'bangalore': 1,
#          'kohinoor': 1,
#          'mr.': 1,
#          'indraneel': 1,
#          'corporate': 1,
#          'reuired': 1,
#          'requirment': 1,
#          '30': 1,
#          'accridngly': 1,
#          'proceed': 1,
#          'personal': 1,
#          'tr3bg': 1,
#          '2022.post': 1,
#          'interior': 1,
#          'designer': 1,
#          'turnkey': 1,
#          'projects': 1,
#          'bhuvnesh': 1,
#          'specs': 1,
#          '29thsep2021': 1,
#          '-no': 1,
#          'such': 1,
#          'driving': 1,
#          'folloup': 1,
#          'posted': 1,
#          '09-02-2022': 1,
#          'converted': 1,
#          'csr': 1,
#          'activity': 1,
#          '24th': 1,
#          'align': 1,
#          'apple': 1,
#          'devices': 1,
#          'mandatory': 1,
#          'arrange': 1,
#          'go': 1,
#          'each': 1,
#          'qty': 1,
#          'wants': 1,
#          'status': 1,
#          'calling': 1,
#          'reaching': 1,
#          'out': 1,
#          'callls': 1,
#          'datasheet': 1,
#          'shalll': 1,
#          'folllllow': 1,
#          'select': 1,
#          'id_timeline': 1,
#          'tracked': 1,
#          '10th': 1,
#          'keen': 1,
#          'explore': 1,
#          '15': 1,
#          'proposal': 1,
#          'submitted': 1,
#          'covid': 1,
#          'md': 1,
#          'comin': 1,
#          'got': 1,
#          'outside': 1,
#          'tentative': 1,
#          'ne': 1,
#          'tr3bf': 1,
#          'nashik': 1,
#          'wk': 1,
#          'conference': 1,
#          'allign': 1,
#          'her': 1,
#          "'ll": 1,
#          'uv': 1,
#          '40': 1,
#          '10': 1,
#          'because': 1,
#          'convince': 1,
#          'client.they': 1,
#          '20th': 1,
#          'about': 1,
#          'finalise': 1,
#          'interersted': 1,
#          'series': 1,
#          '29th': 1,
#          'bodeli': 1,
#          'po': 1,
#          '|': 1,
#          '11th': 1,
#          'june-': 1,
#          'lakhs': 1,
#          'prospetive': 1,
#          'buyer': 1,
#          'vis': 1,
#          'networks': 1,
#          'cross-checking': 1,
#          'time': 1,
#          'air': 1,
#          'conditioners': 1,
#          'reqirements': 1,
#          'withdrawn': 1,
#          'decission': 1,
#          'evaluatuating': 1,
#          'months-': 1,
#          'requiment': 1,
#          'cusotmer': 1,
#          'understanding': 1,
#          'waiting': 1,
#          'reply': 1,
#          'mai': 1,
#          'she': 1,
#          'binary': 1,
#          '@': 1,
#          '1.23l': 1,
#          '75tr': 1,
#          'residential': 1,
#          'nextweek': 1,
#          'valid': 1,
#          'anwering': 1,
#          'hotel': 1,
#          '4': 1,
#          'immediate': 1,
#          'treid': 1,
#          '80k': 1,
#          'conect': 1,
#          'friday': 1,
#          'willing': 1,
#          'future': 1,
#          'whatsap': 1,
#          'belongs': 1,
#          'maharashtra': 1,
#          'inbuilt': 1,
#          'ops': 1,
#          'option': 1,
#          'il220300046498': 1,
#          'bought': 1,
#          'maxhub': 1,
#          'bihar': 1,
#          'studio': 1,
#          'setup': 1,
#          '30/04': 1,
#          'sangli': 1,
#          'shortthrow': 1,
#          'projector': 1,
#          'ho': 1,
#          'ahmedabad': 1,
#          '!': 1,
#          'finance': 1,
#          'accounting': 1,
#          'inquired': 1,
#          'foe': 1,
#          'detais': 1,
#          'tuesday': 1,
#          'still': 1,
#          'tv.s': 1,
#          'gets': 1,
#          'installed': 1,
#          'pan': 1,
#          'india': 1,
#          'cctv': 1,
#          'supplied': 1,
#          '49vl5b': 1,
#          '62000': 1,
#          '49vl5f': 1,
#          '71000.now': 1,
#          '80000': 1,
#          '+': 1,
#          'rechecking': 1,
#          'inquiry.closing': 1,
#          'enquirey': 1,
#          'quality': 1,
#          'speaker': 1,
#          'tracking': 1,
#          'main': 1,
#          'feature': 1,
#          'around': 1,
#          '42': 1,
#          'suggested': 1,
#          'fully': 1,
#          'benq': 1,
#          'differance': 1,
#          '15000': 1,
#          '98': 1,
#          'below': 1,
#          'swtiched': 1,
#          'device': 1,
#          'like': 1,
#          'used': 1,
#          'respondig': 1,
#          'coming': 1,
#          '28th': 1,
#          'came': 1,
#          'receive': 1,
#          '31st': 1,
#          'week.14-06-2022': 1,
#          '18th': 1,
#          'nov-': 1,
#          'pickup': 1,
#          'senses': 1,
#          'few': 1,
#          'confiermed': 1,
#          'name': 1,
#          'purpose': 1,
#          'guided': 1,
#          'b2b': 1,
#          "dind't": 1,
#          'able': 1,
#          'latur': 1,
#          'recently': 1,
#          '65um3df': 1,
#          'unable': 1,
#          'track': 1,
#          'supplier': 1,
#          'uttarpradesh': 1,
#          'state': 1,
#          'mumbai': 1,
#          'concerned': 1,
#          'moment': 1,
#          'ultra': 1,
#          'stretch': 1,
#          '-27th': 1,
#          'reseller': 1,
#          'authorization': 1,
#          '1.25+tax': 1,
#          'regret': 1,
#          'offer': 1,
#          'explained': 1,
#          'why': 1,
#          'better': 1,
#          'premium': 1,
#          'day': 1,
#          'since': 1,
#          'long': 1,
#          'finalized': 1,
#          'exiting': 1,
#          'answered': 1,
#          'correct': 1,
#          'trueview': 1,
#          'kinnari': 1,
#          'eletronis': 1,
#          'vatwa': 1,
#          'bid': 1,
#          'know': 1,
#          'request': 1,
#          'shailja': 1,
#          'reconnect': 1,
#          'dicsussed': 1,
#          'sept-': 1,
#          'schedule': 1,
#          'fund': 1,
#          'options': 1,
#          'viewsonic': 1,
#          'user': 1,
#          'aligarh-up': 1,
#          'plz': 1,
#          '14th-feb-2022': 1,
#          'details.awaiting': 1,
#          'worked': 1,
#          'crew': 1,
#          'commercials': 1,
#          'mayur': 1,
#          'electronic': 1,
#          'shubham': 1,
#          'who': 1,
#          'student': 1,
#          'speak': 1,
#          'sir': 1,
#          'weeks': 1,
#          '45': 1,
#          'solutions': 1,
#          'undertanding': 1,
#          'domestic': 1,
#          'biz': 1,
#          '28/09': 1,
#          'cutsomer': 1,
#          'years': 1,
#          'never': 1,
#          'till': 1,
#          'twice': 1,
#          'reponse': 1,
#          'addressed': 1,
#          're-check': 1,
#          'screen': 1,
#          'supply': 1,
#          'govt.': 1,
#          'conncgt': 1,
#          'requierements': 1,
#          'skus': 1,
#          'here': 1,
#          'facing': 1,
#          'challenge': 1,
#          'stock': 1,
#          'lost': 1,
#          'unavailabilty': 1,
#          'detailed': 1,
#          '6th': 1,
#          '24': 1,
#          'mentioned': 1,
#          'sizes': 1,
#          'rerquirement': 1,
#          'emailed': 1,
#          'looping': 1,
#          'meet': 1,
#          'tab': 1,
#          '25': 1,
#          'mount': 1,
#          'ref': 1,
#          '4k': 1,
#          '6k': 1,
#          'exactly': 1,
#          'cancle': 1,
#          'retail': 1,
#          'monitor': 1,
#          'conference/meeting': 1,
#          'room/collaboration': 1,
#          'spaces': 1,
#          'holded': 1,
#          're-iniitaties': 1,
#          'abrupt': 1,
#          'ago': 1,
#          'rude': 1,
#          'behaviour': 1,
#          'marketing': 1,
#          'dec': 1,
#          'jan': 1,
#          'software': 1,
#          'finalised': 1,
#          '9th': 1,
#          'oct-': 1,
#          'online': 1,
#          'jan.': 1,
#          'pitched': 1,
#          '110': 1,
#          'prgress': 1,
#          'knew': 1,
#          'comes': 1,
#          'udpate': 1,
#          'transparent': 1,
#          'cost': 1,
#          'wit': 1,
#          'create': 1,
#          'clarfying': 1,
#          'event': 1,
#          'organization': 1,
#          'rental': 1,
#          "'s": 1,
#          'billing': 1,
#          'getting': 1,
#          'jaipur': 1,
#          'operating': 1,
#          'rc': 1,
#          'subway': 1,
#          'franchisee': 1,
#          'elsewhere': 1,
#          'mails': 1,
#          'find': 1,
#          'net': 1,
#          'kiosk': 1,
#          'dinalised': 1,
#          'visiting': 1,
#          'experience': 1,
#          'centre': 1,
#          'segment': 1,
#          '85': 1,
#          'hall': 1,
#          'development': 1,
#          'finalization': 1,
#          'place': 1,
#          'ready': 1,
#          'discussing': 1,
#          '09-06-2022-': 1,
#          'today': 1,
#          '14-06-2022-': 1,
#          'shred': 1,
#          'match': 1,
#          'technical': 1,
#          'specification': 1,
#          'cheking': 1,
#          'clising': 1,
#          'china': 1,
#          'government': 1,
#          'present': 1,
#          '4/8': 1,
#          '14:00~15:00': 1,
#          'idbs': 1,
#          '22': 1,
#          'morning': 1,
#          'internally': 1,
#          'lookong': 1,
#          'última': 1,
#          'revisión': 1,
#          '26/07/21': 1,
#          '25-nov-2021': 1})

# %%
unique_values = df_train['expected_timeline'].nunique()

# 결과 출력
print(f"unique 값: {unique_values}")

# 각 숫자의 빈도와 함께 출력 (null 값 포함)
value_counts = df_train['expected_timeline'].value_counts(dropna=False)

# 결과 출력
print("빈도:")
for value, count in zip(value_counts.index, value_counts.values):
    print(f"{value}: {count}")
# Out:
# unique 값: 449
# 빈도:
# nan: 30863
# less than 3 months: 17250
# 3 months ~ 6 months: 5026
# more than a year: 3023
# 9 months ~ 1 year: 1101
# 6 months ~ 9 months: 1098
# less than 6 months: 108
# etc.: 95
# less_than_3_months: 76
# being followed up: 66
# being followed up.: 24
# the client is not having any requirement hence closig in system. although the details of idb are mailed to client.: 21
# no requirement: 12
# 3_months_~_6_months: 9
# didn't respond: 7
# duplicate lead: 6
# 9_months_~_1_year: 6
# forwarded to bdo, being followed up: 5
# details send: 5
# couldn't connect: 5
# the client is not having any requirement, he was only browsing through the produt hence closig in system. although the details of idb are mailed to client.: 5
# quote send: 5
# details shared: 5
# rnr: 5
# 6_months_~_9_months: 4
# not answering call: 4
# budget issue: 4
# more_than_a_year: 4
# details shared.: 3
# not answering call, lead shared with rd: 3
# assigned to partner. intial meeting done. will convert to opp post complete info: 3
# not required: 3
# already touch with customers: 3
# december 2022: 3
# call back later: 3
# not interested: 3
# less then 6 months: 2
# not reachable: 2
# tried couple of times but he is not responding. we will try again: 2
# tried to reach several times but no response: 2
# less than 5 months: 2
# more then 3 months: 2
# due to financial reasons, client have dropped purchase plan. although the details of idb are mailed to client.: 2
# details shared, being followed up: 2
# not lifted: 2
# low budget: 2
# price shared: 2
# november 2022: 2
# no response.: 2
# fu under progress.: 2
# forwarded to bdo to followup.: 2
# fu under progress: 2
# he client is not having any requirement hence closig in system. although the details of idb are mailed to client.: 2
# october 2022: 2
# not responding: 2
# tried to reach customer but no response. lead forwarded to partner for further follow up: 1
# update---27th aug--customer has to come for product demo: 1
# he is looking for interactive display. quote shared with him.: 1
# looking for commercial tv 55". details mailed to client,they have no plans for now to buy hence closing in the system.: 1
# update- as per customer no enquiry was made.: 1
# quote shared with him and he will update us after demo: 1
# customer budget is 1.25+tax for 75 inch idb. i have given our no regret offer and also explained why lg is better and premium. he said he will come back in a day or two.: 1
# reseller want to have gem authorization.: 1
# details shared with customer, also i had shared lead with rd to take it further: 1
# already in touch with him since long. he has not finalized yet. lead forwarded to rd: 1
# exiting customer: 1
# already working with end user on this requirement.: 1
# purchased viewsonic panel: 1
# demo to be planned: 1
# quotation shared with him for idb. he dont have enough fund as of now. he is just evaluating options.: 1
# update- 8th sept- details shared. will confirm demo schedule of next week.: 1
# dicsussed with client,details shared on mail, client have no budgets to buy now hence closing in the system.: 1
# not answering call, sales remarks: tried to reach him multiple times but he is not responding. request to shailja to reconnect with customer. we are dropping this lead for now.: 1
# asked to call back later, i had shared this lead with rd to take it further.: 1
# following up: 1
# called to know the price of idb: 1
# kinnari eletronis vatwa has bid for the same. and they are going to purchase from them.: 1
# client is exploring. he will discuss once details sent. details mailed to him. as per recent discussion, he is not exploring as of now.: 1
# discussed with the client. he dont have budgets. details mailed. he wont buy now hence closing in the system.: 1
# call not connecting: 1
# quote shared for 86 inch. he is evaluation local brand of trueview: 1
# drop, now not intrested: 1
# contact details provided are wrong, sent mail for correct contact details.: 1
# drop, wrong number: 1
# less than 3 months. customer not answered . to call back: 1
# quotation shared for ultra stretch and 49vl5g. he will check with management and update us: 1
# he needs for home purpose and is a consumer client. spoke and guided on the details and channel. not a b2b requirement.: 1
# not interested at the moment: 1
# concerned person not available, will call later: 1
# mobile is switched off. tried 3 times: 1
# customer want product t 15000: 1
# customer purchase benq for price differance: 1
# spoke with customer, he is looking for dot led product in 42 inch, i have suggested him our 43 inch signage but he want fully outdoor led. i have shared the details of our 43 inch display: 1
# customer has not answering call / customer want 86" interactive display, he will purchase within next 6 month, we are forwarding to local rd to take this further: 1
# budget problem.: 1
# client have seen the demo. he needed for bigger room and the camera quality and speaker tracking were the main required feature. as of now, his budget is around 2 lacs and need bigger size solution. there is no response from client post demo hence closing: 1
# delhi enquirey: 1
# custome purchase  consumer product: 1
# purchase vu brand: 1
# known partner and we have installed 3 video walls pan india for cctv. we supplied 49vl5b at rs. 62000 and then again 49vl5f at rs. 71000.now the available model is 49vl5g at 80000 + which partner is rechecking and hence made inquiry.closing the inquiry si: 1
# already our customer, have shared prices for new requirement: 1
# customer phone is gets switched off: 1
# he asked to share budgetory quote, he will check and confirm if he will require the product.: 1
# not interested in commercial tv.s: 1
# requirement of idb, budget is very low. shared details on whatsapp. 1 unit required. rd is following up.: 1
# drop, still no plan for purchase: 1
# requirement of 75tr3dj –  demo, details shared with rd: 1
# quotation sent – 75tr3dj , work in progress, he will buy after 2 months. he has not even seen the quote yet.: 1
# couldnt connect: 1
# dropped.. have purchased cloudwalker: 1
# he want 98 inch in below 2 lacs: 1
# phone swtiched off: 1
# dropped, requires device like one quick share to be used with samsung tv: 1
# repeat enquiry: 1
# discussed and shared details with client for digital signage. they are not planning to purchse the same currently hence closing in the system.: 1
# requirement of 75tr3dj –  demo, lead shared with mumbai team.: 1
# uttarpradesh state lead: 1
# discussed with the client they purchased 65um3df from the channel. unable to track the supplier. hence closing in the system. mail sent to client for our display range.: 1
# recently no requirement, dropped: 1
# he want demo in latur. and also dont have much budget. partner followed up multiple times but no response.: 1
# tried contact him but couldn't able to connect. lead forwarded to rd: 1
# dind't respond: 1
# one month: 1
# client was inquiring for prices. already quoted by few partners. they even purchased as per recent update but client has not confiermed partner name.: 1
# drop, budget problem now phone not respondig: 1
# he is comparing with senses which is local brand.: 1
# didn't pickup the call: 1
# connecting for issue: 1
# tried to reach him but no response. i will call him again. 18th nov- i called him again and he will send the requirement on mail.: 1
# details shared with rd for further action,: 1
# quote shared with customer, he will confirm after 2 months. lead shared with partner.: 1
# custome has not receive call. as on 31st may- spoke with customer, he will come for demo in next week.14-06-2022: 1
# customer will be coming for demo on 28th may. customer did not came for demo. i have shared details with rd to take it further. hence dropping this lead: 1
# he want 65 inch at 50k: 1
# he is requesting demo in aligarh-up, plz share to up person.: 1
# call back tomorrow 28/09: 1
# purchased some local panel, budget issue: 1
# he want 32 inch tv for signage. details shared with him.: 1
# update- details already shared with customer. evaluation is on going.: 1
# customer is busy ask us to call again ,following: 1
# duplicate lead - il220100042906. discussed with client. their vc hall is under development. onequick details mailed to client. they will call us for demo and purchase finalization once their vc place is ready.: 1
# call back later, in first week march: 1
# need for home segment. they purchased vu 85 inch tv for their home: 1
# he is looking for consumer product for home: 1
# update--4th aug--customer visiting experience centre on 8th sept: 1
# discussed with client. details mailed client dont have budget for purchase now hence closing in the system: 1
# communication number not available.: 1
# under discussion, requirement not dinalised yet: 1
# no response: 1
# already touch with customer for kiosk requirement: 1
# already working on idb will create opp post clarfying on signage: 1
# not picking calls, called many times: 1
# discussed with client, details shared on mail client have no purchase plans for now hence closing the same in system.: 1
# requirement of 65tr3dj: 1
# already connect with partner: 1
# update--14th sept--customer will discuss in detail tomorrow: 1
# will come back once it is required: 1
# busy, call later: 1
# no response on mails from the client. couldnt find any contact details on net as well. hence dropping in the system. although idb and onequick details shared on email.: 1
# client is cross checking on prices. its a rc case of subway and the franchisee is trying to get pricing from elsewhere.: 1
# customer getting price from jaipur which low than our operating price.: 1
# partner is working on existing requirement. he is connected with our disti's for billing.: 1
# dont have budget. he want dot led: 1
# quotation shared with customer, he will confirm back after discussing with management 09-06-2022- as on today 14-06-2022- not answering call hence  i am dropping this lead. details shred with rd take it for further: 1
# duplicate lead - il220100042906. less than 3 months: 1
# we are not going to match technical specification: 1
# not responding to calls: 1
# quote shared with him.: 1
# 25-nov-2021  no mobile number, sent a mail to customer: 1
# the client is not having any requirement he was just browsing for products hence closig in system. although the details of idb and video walls are mailed to client.: 1
# asked to share details on mail. he will update if there is any requirement: 1
# última revisión: 26/07/21: 1
# drop, lookong for consumer product: 1
# he is in discussion internally and will update.: 1
# drop, not intrested: 1
# not required now: 1
# asked to call back tomorrow morning, not responding: 1
# november 22: 1
# mailed details & price of 55 inches: 1
# require demo after 20 may.: 1
# price shared with customer. he is looking for some idbs. need to take follow up: 1
# 14:00~15:00: 1
# 9 months - 1 year: 1
# discussed with client,details mailed for idb and one quick, they have no plan to buy for now hence closing in the system.: 1
# 4/8 months: 1
# client is not having any requirement, he was only browsing through the produt hence closig in system. although the details of idb are mailed to client.: 1
# at present not required,: 1
# looking for not made in china active outdoor led for government project: 1
# requirement of video wall. client is cheking on prices. already 2 partners working. its ongoing case hence clising in system.: 1
# he is an event organization and looking for rental displays. hence dropping in system.: 1
# repeat inquiry, we already knew on the client requirement. we are in touch with them and if any requirement comes, we will udpate. as of now, the transparent led they need is not available with us and the available product cost expectation is very low wit: 1
# he has asked to connect next week. he want to see the physical demo.: 1
# already purchase with rd: 1
# update-- 4th aug--detailed discussion to be done on 6th aug: 1
# quote shared with customer. he will revert with an update: 1
# we were already working here, we are facing challenge as we dont have 49vl5g in stock. order lost in march due to unavailabilty of 49vl5g.: 1
# update- 14th sept-- more details to be shared by client: 1
# spoken to partner, have no any requierements for now, have mailed the details to him, he wont purchase any skus for now hence closing in the system.: 1
# discussed with client, they were just evaluating the product, they have no plans to buy the same, hence closing in the system.: 1
# drop, requirement of interactive touch screen to supply in govt., conncgt with partner: 1
# existing partner, discussed and addressed the concern. the partner had taken pricing and wanted to re-check as the model quoted is changed.: 1
# we are already in touch with this cutsomer from last 2 years, he has never purchased any product till date. i called him up twice but no reponse.: 1
# september 2022: 1
# not responding.: 1
# update- 4th aug- customer asked to call on monday: 1
# forwarded to aurangabad rd for further process: 1
# need to do domestic trade biz: 1
# email send for details. client is exploring on solutions but only for their undertanding.: 1
# 45 days: 1
# spoke with shubham who is student. he said he will speak with his sir and revert back after 2 weeks.: 1
# mayur electronic connect with client: 1
# drop, already done with partner: 1
# existing case worked by our disti, crew business, hence closing as client is only checking for commercials: 1
# 14th-feb-2022 shared details.awaiting update from customer.: 1
# details shared, to plan demo in december: 1
# provided model and price as per requirement.: 1
# price share with customer. our rd is following up with him but customer is not responding: 1
# discussed with client. they need 24 inch display for digital signage. mentioned for our available sizes, he shall revert.: 1
# the rerquirement is for pune. emailed client looping pune team to meet and visit the client.: 1
# details send quote require: 1
# small size tab required: 1
# we have pitched 110 inch fu under prgress: 1
# asked to contact him after 8th jan.: 1
# customer has been not  answering call: 1
# requirement is for pune. looped pune team. although the partner is checking prices for an existing case. closing the lead in system as pune team is already working.: 1
# call not picking: 1
# want to do trade product business: 1
# update- 9th oct- details shared. will confirm for online demo next week: 1
# discussed with partner. he works with cloudwalker and wanted to connect with us for some product details. as of now, dont have any inquiry to work and hence closing in system.: 1
# phone number not available: 1
# meeting date to be finalised: 1
# already in touch with partner.: 1
# looking for home use: 1
# details shared follow up under progress.: 1
# require only cms software.: 1
# very abrupt customer. said the inquiry was made months ago and was rude enough. closing in the system as the client behaviour has no scope to discuss on requirement. need marketing team to check if the case was received in dec or jan as per client.: 1
# client was exploring on products but he dont have any plans to purchase. currently he have holded on his requirement and will connect if it re-iniitaties.: 1
# conference/meeting room/collaboration spaces: 1
# budget problem: 1
# asked to call back tomorrow, i had shared this enquiry with rd.: 1
# want to take retail monitor: 1
# project cancle: 1
# not answering tried several times. details shared with rd.: 1
# the client is looking for small size displays of 20 inch to 25 inch to mount on ref. the budget is 4k to 6k. not exactly our requirement: 1
# known partner and already working on a case. only cross checking prices hence dropping.: 1
# he want demo in sangli, i have looped with local partner.: 1
# discussion to be done with customer: 1
# meeting planned for further discussion: 1
# tried calling the client, no response from client, i have mailed idb details, will keep follow up & update: 1
# discussed with client, he shall send the details of their office requirement: 1
# customer has not answering call: 1
# will come for the demo: 1
# quote shared with customer, lead shared with partner to take it further.: 1
# quote sent, the client is required demo in june: 1
# demo planned, will update further status once its completed: 1
# call and discused to custome customer wants demo.: 1
# he want demo next week: 1
# customer will come for demo in next week, than he will decide further: 1
# remarks : customer looking for 65 inches and 75 inches  each 1 qty: 1
# quote send meeting pending: 1
# under discussion: 1
# quote sent to customer.: 1
# client is looking for 86" display with vc solution, they will go for demo next week and decide on procuring our tr3dj, details shared with client on mail.: 1
# need to arrange quote and demo.: 1
# discussed with client. will plan for demo.: 1
# require demo: 1
# discussed with client. we need to align demo. the expectation is connecting apple devices but not mandatory. once demo is done, we shall update: 1
# details send require demo: 1
# demo scheduled for 24th oct: 1
# discussed with client they need for csr activity. prices expectation is very much low.: 1
# client was busy, asked to call back later, interested in exploring our idb: 1
# tried reaching out to client no response to callls so i have shared the datasheet, shalll folllllow up and update: 1
# update- call to be made on tuesday: 1
# he want demo next month at pune - 15 may: 1
# get back in 1 wk: 1
# demo done: 1
# he want physical demo of tr3bf in nashik. but there budget is also very low. so first he will discuss with management on budget then confirm back for demo: 1
# less than 3 months ,meeting with the customer for the more details and tentative boq will ne 32 and 43: 1
# they are consultant and i am already in touch with customer.: 1
# 14th aug- aggressive price required as he has got price from outside delhi: 1
# proposal submitted , due to covid md is not comin to office for the meeting.: 1
# discussed with client. demo aligned. once done, will update.: 1
# order taken: 1
# aggressive price required: 1
# client was keen to explore our idb sku, in follow up: 1
# (select id_timeline): 1
# quote send require demo in next week.: 1
# quote send next month require: 1
# spoke with customer, will be sharing details on email.: 1
# quote send require demo.: 1
# call after 3 june: 1
# demo done and details shared: 1
# call and discused no requirement.: 1
# demo completed, customer asked to come feb 10th for closure.: 1
# demo aligned for client: 1
# client is not responding calls, following up and keep the update tracked: 1
# converted this lead into opportunity.: 1
# 09-02-2022 requested for boq of requirement: 1
# client was driving and asked to call back later, will folloup and keep posted.: 1
# discussed with client details mailed. they have budge issue for now so they wont buy hence closing in yhe system.: 1
# already shared quotation through si.: 1
# discussed with client. details mailed for onequick, they are not planning to buy the same for now hence closing in the system.: 1
# customer want demo of idb. he will come for demo in next week. after following up with customer multiple times there is no update. lead has been forwarded to rd.: 1
# scheduling a meeting: 1
# partner is already in touch with our rd, orno. the partner needs to cross check on the information as the size is changed from 49 to 50 now. closing the opprtunity as its existing with rd.: 1
# details shared with customer. as on 4th may- tried multiple times but not reachable: 1
# update- 13th spet--follow up to be done on 15th sept: 1
# il220100042906 - repeat inquiry hence closing this in system.: 1
# demo to be aligned: 1
# he is looking for video wall & idb for his office. our bdo jayant is in touch with him and sharing the required details to customer.: 1
# not require: 1
# purchase planning after 3 months: 1
# partner is into static signages. he need to connect for digital signage but he himself is manufacturer. although a mail initaited for any requirements with led team to take it ahead. as of now, there is no scope hence closing in system.: 1
# requires detail for tender. no purchase requirement right now.: 1
# discused with ankit in dehli: 1
# tried to reach him multipe times from last 7 days but couldn't get through: 1
# update- 7th aug--demo given. customer will confirm next week: 1
# repeated inquiry from client. he was just inquiring but have not confimred on purchase. we have tried mulitple times but client is not interested in buying.: 1
# client not interested in product.. receing call and not answering properly: 1
# already close in july purchse with rd: 1
# partner was exploring on eol model for some requiremeent. no designated sales or closure expected hence closing in the system.: 1
# quote has been sent to customer.: 1
# quotation shared.: 1
# budget low hence client have not went ahead.: 1
# invalid lead: 1
# demo scheduled for first week feb: 1
# he want demo in aurangabad, details shared with rd: 1
# quotation shared in communication: 1
# 29thsep2021:-no such requirement as of now: 1
# is an interior designer. working on turnkey projects. mr bhuvnesh is in contact and shared specs and prices.: 1
# didn't respond to calls: 1
# discussed with the client, tr3bg & one quick works demo scheduled on 27th july 2022.post demo they will decide on procuring the unit.: 1
# spoken to client, he will check if they need demo and confirm: 1
# need to discuss with client in next two months. they need to check the product and accridngly proceed for personal use.: 1
# eol model new model quote requirment after 30 days.: 1
# size not available: 1
# require demo price send: 1
# reuired for office. asked to share quotation: 1
# already in discussion with partner from bangalore (kohinoor) and with mr. indraneel from corporate office: 1
# details shared with partner. he has quoted in our existing customer only.: 1
# client shall get back for exploring demo of idb, post that they will decide on procuring the same.: 1
# spoke with customer, details needs to share on mail. also they want demo: 1
# don’t have budget: 1
# details shared with customer, he will update on further action after evaluating other brands as well.: 1
# spoke with custome he want 43" tv: 1
# the partner is checking price for an ongoing case of barc. we have discussed on new case with the partner.its useful to take our discussion further for new inquries.closing the opportunity in system as of now as its made only for cross checking prices.: 1
# the client budget is within 1 lacs they need 55 inch aio solution. as per discussion, they are comparing with jabra and we proposed to check if they need only displays. but due to budget contraint, they are dropping the idea.: 1
# detail shared with him on email. he is looking for one unit of 65 inch for his conference room: 1
# already in touch with customer: 1
# mr rajnikant is allign with the client.: 1
# busy. need to call back: 1
# not reachable , details shared with rd: 1
# same as lead no  il220300046498 hence dropping. duplicate lead.: 1
# requirement of 75tr3dj –  demo required: 1
# requirement of 65tr3dj –  demo reqired, lead shared with rd: 1
# client is not looking now and he was interested with only inbuilt ops option. hence closing in system as he is not responding to calls.: 1
# lead belongs to maharashtra: 1
# drop not willing to buy now.. will do in future.. details shared on whatsap: 1
# details shared with concern person. will ask bdo to follow up: 1
# already in touch with there team: 1
# discussed with client. they have no budgets for purchase for now, they wont buy hence closing in the system.: 1
# need to call on friday 27th: 1
# details shared fu under progress: 1
# he just need budgetory pricing. we have shared the details with him and requested him to come for demo: 1
# couldn't conect: 1
# not responding, details shared with local rd: 1
# require 65 inch idb under 80k: 1
# treid many times but phone not reachable: 1
# dont have any immediate requirement. he may purchase after june: 1
# needs hotel tv after 4 months, will call us.: 1
# client not anwering calls and asked there is no requirement. he was trying to check prices for one 65 touch requirement of existing client.: 1
# dropped. contact no not valid: 1
# meeting planned nextweek.: 1
# due to budget issue, customer has bought maxhub panel.: 1
# next week he will come for demo at lg office: 1
# his budget is under 50k only: 1
# he will call back if needed: 1
# not responding tried many times: 1
# idb detais send: 1
# finance and accounting consultant. inquired foe 43 inch aio but dont have plans to buy. details discussed.: 1
# discussed with client, details mailed they are not planning to purchase for now hence closing in the system.: 1
# no drop this lead, no budget!: 1
# asked to call later.: 1
# requirement of 65tr3dj –  demo required: 1
# not reachable, i had shared lead with partner: 1
# connect with partner: 1
# quotation shared with customer: 1
# rajnikant is working in this case ho in ahmedabad and its under process.: 1
# customer need shortthrow projector: 1
# budget issue.: 1
# drop no plan for purchase: 1
# not answering call, shared lead with rd: 1
# tried to reach him multiple times, but couldn't get thru.: 1
# call back again on 30/04: 1
# quote shared but there budget is very low: 1
# connected with partner for studio setup with camera: 1
# requirement of 65tr3dj and customer want demo, details shared with rd: 1
# its bihar customer: 1
# customer is looking for residential 43 inch display for home use: 1
# details shared for 75tr, followup in first week of oct: 1
# spoke with her and shared the details for signage displays.: 1
# discussed with client.they are looking for aio solution with vc. they will call after 20th for the demo and then purchase through gem.: 1
# no further revert & clarity after sharing details.: 1
# no contact number, i have dropped a email requesting for the same.: 1
# september: 1
# customer not answering call, will call him again and update: 1
# received po.: 1
# 3 months: 1
# bodeli, requirement pending new quote send close in this month end.: 1
# discussed with the client. asked to call back on monday will keep a follow up.: 1
# discussed with the client. they are interersted in our tr3dj series demo planned for 29th june post they will plan on procurement. will keep update.: 1
# discussed with the client. prices shared for onequick and idb on mail. customer to confirm about demo of the sku and finalise on procurement.: 1
# his budget is very low but we are trying to convince him for 65 inch: 1
# purchased from binary @ 1.23l: 1
# already in touch with customer from last 10 days. dropping it because we are already in touch: 1
# they are having requirement of 40 displays. customer need aggressive pricing than samsung.: 1
# customer visit at uv business and see the demo within 2 to 3 days.: 1
# require quote: 1
# spoken to client, he will connect once he discuss on requirement: 1
# customer has not answering call / quotation has been send to customer: 1
# details shared on whatsapp, he'll revert back.: 1
# we are already in touch with customer thru partner: 1
# he is looking for an interactive display. discussed with client, will update as the case progress.: 1
# discussed with client, quote sent.: 1
# he is looking for display for his restaurant. he has asked to contact him after 1 month as restaurant work is under progress: 1
# his budget is very low.: 1
# not answering call | as on 11th june- customer phone is not reachable. i am dropping this lead and forwarding to partner.: 1
# looking for active led in a range of 5 lakhs . not a prospetive buyer: 1
# not answering call, details shared with rd: 1
# the client is not having any requirement, she was only browsing through the produt hence closig in system. although the details of idb are mailed to client.: 1
# asked to send details: 1
# not lifted, call later: 1
# details shared with customer on mail: 1
# details shared with customer on mai: 1
# customer ask to call back tomorrow: 1
# looking for outdoor display. cusotmer has no clarity on the solution. email shared for understanding and waiting for reply: 1
# less than 3 months- outdoor led requiment: 1
# discussed with client. they are not evaluatuating idb as of now, they have no plans to buy hence closing in the system.: 1
# asked to call on 4th may: 1
# asked to call next week: 1
# withdrawn the decission to purchase: 1
# no reqirements: 1
# looking for air conditioners: 1
# not answering call, will try to reach him again.: 1
# cms reqired: 1
# no requirement of this time: 1
# not reachable , lead shared with partner: 1
# discussed with client. details mailed to client. no budgets for now wont buy hence closing in the system: 1
# our partner, vis networks is working on this inquiry and client is cross-checking the prices. hence closing in the system.: 1
# up to december: 1

# %%
timeline_mapping = {
    # 날짜
    "less than 3 months": "0-3m",
    "less_than_3_months": "0-3m",
    
    "3 months ~ 6 months": "3-6m",
    "3_months_~_6_months": "3-6m",
    
    "6 months ~ 9 months": "6-9m",
    "6_months_~_9_months": "6-9m",
    
    "9 months ~ 1 year": "9-12m",
    "9_months_~_1_year": "9-12m",

    "up to december": "1y",
    "more than a year": "1y",
    "more_than_a_year": "1y",

    "couldn't connect": "no response",
    "rnr": "no response",
    
    # 오타
    "reponse": "response"
}

# 레이블을 통일된 형태로 매핑
df_train['expected_timeline'] = [timeline_mapping.get(label, label) for label in df_train['expected_timeline']]

# %% [markdown]
# # 요구 사항 분류 (requirement)
# - not, no 로 부정 분류
# - requi, reqi 로 시작하는 오타가 있음

# %%
for index, row in df_train.iterrows():
    current_value = row['expected_timeline']

    # NaN 값 체크
    if pd.notna(current_value):
        original_value = current_value
        updated_value = None

        # requi 또는 reqi를 포함하면서 부정형이 들어가 있는 경우를 'no requirement'로 분류
        if ('requi' in current_value or 'reqi' in current_value) and ('no' in current_value or 'not' in current_value):
            updated_value = 'no requirement'
        # requi 또는 reqi를 포함하면서 부정형이 없는 경우를 'requirement'로 분류
        elif 'requi' in current_value or 'reqi' in current_value:
            updated_value = 'requirement'
        
        # 기본 케이스: 어떤 조건도 충족되지 않으면 원래 값 유지
        if updated_value is None:
            updated_value = original_value

        df_train.at[index, 'expected_timeline'] = updated_value

# %%
for index, row in df_train.iterrows():
    current_value = row['expected_timeline']

    # NaN 값 체크
    if pd.notna(current_value):
        original_value = current_value
        updated_value = None

        if 'not intere' in current_value:
            updated_value = 'no requirement'

        # 기본 케이스: 어떤 조건도 충족되지 않으면 원래 값 유지
        if updated_value is None:
            updated_value = original_value

        df_train.at[index, 'expected_timeline'] = updated_value

# %% [markdown]
# # 커뮤니케이션 사항 분류 (reponse)
# - didn't not no 로 부정 분류

# %%
for index, row in df_train.iterrows():
    current_value = row['expected_timeline']

    # NaN 값 체크
    if pd.notna(current_value):
        original_value = current_value
        updated_value = None

        if 'resp' in current_value and ('no' in current_value or 'not' in current_value or "didn't" in current_value):
            updated_value = 'no response'
       
        elif 'resp' in current_value:
            updated_value = 'reponse'

        # 기본 케이스: 어떤 조건도 충족되지 않으면 원래 값 유지
        if updated_value is None:
            updated_value = original_value

        df_train.at[index, 'expected_timeline'] = updated_value

# %% [markdown]
# # 요구 사항 분류 (follow)

# %%
for index, row in df_train.iterrows():
    current_value = row['expected_timeline']

    # NaN 값 체크
    if pd.notna(current_value):
        original_value = current_value
        updated_value = None

        if 'follow' in current_value:
            updated_value = 'follow'

        # 기본 케이스: 어떤 조건도 충족되지 않으면 원래 값 유지
        if updated_value is None:
            updated_value = original_value

        df_train.at[index, 'expected_timeline'] = updated_value

# %% [markdown]
# # 요구 사항 분류 (details)

# %%
for index, row in df_train.iterrows():
    current_value = row['expected_timeline']

    # NaN 값 체크
    if pd.notna(current_value):
        original_value = current_value
        updated_value = None

        if 'details' in current_value:
            updated_value = 'details shared'

        # 기본 케이스: 어떤 조건도 충족되지 않으면 원래 값 유지
        if updated_value is None:
            updated_value = original_value

        df_train.at[index, 'expected_timeline'] = updated_value

# %% [markdown]
# # 커뮤니케이션 분류 (not answering == no response)

# %%
for index, row in df_train.iterrows():
    current_value = row['expected_timeline']

    # NaN 값 체크
    if pd.notna(current_value):
        original_value = current_value
        updated_value = None

        if 'not answering' in current_value:
            updated_value = 'no response'

        # 기본 케이스: 어떤 조건도 충족되지 않으면 원래 값 유지
        if updated_value is None:
            updated_value = original_value

        df_train.at[index, 'expected_timeline'] = updated_value

# %% [markdown]
# # 커뮤니케이션 분류 (call back, call later)

# %%
for index, row in df_train.iterrows():
    current_value = row['expected_timeline']

    # NaN 값 체크
    if pd.notna(current_value):
        original_value = current_value
        updated_value = None

        if 'call back' in current_value:
            updated_value = 'call back'

        elif 'call later' in current_value:
            updated_value = 'call back'

        # 기본 케이스: 어떤 조건도 충족되지 않으면 원래 값 유지
        if updated_value is None:
            updated_value = original_value

        df_train.at[index, 'expected_timeline'] = updated_value

# %%
for index, row in df_train.iterrows():
    current_value = row['expected_timeline']

    # NaN 값 체크
    if pd.notna(current_value):
        original_value = current_value
        updated_value = None

        if 'duplicate lead' in current_value:
            updated_value = 'duplicate lead'

        # 기본 케이스: 어떤 조건도 충족되지 않으면 원래 값 유지
        if updated_value is None:
            updated_value = original_value

        df_train.at[index, 'expected_timeline'] = updated_value

# %%
unique_values = df_train['expected_timeline'].nunique()

# 결과 출력
print(f"unique 값: {unique_values}")

# 각 숫자의 빈도와 함께 출력 (null 값 포함)
value_counts = df_train['expected_timeline'].value_counts(dropna=False)

# 결과 출력
print("빈도:")
for value, count in zip(value_counts.index, value_counts.values):
    print(f"{value}: {count}")
# Out:
# unique 값: 249
# 빈도:
# nan: 30863
# 0-3m: 17326
# 3-6m: 5035
# 1y: 3028
# 9-12m: 1107
# 6-9m: 1102
# follow: 109
# less than 6 months: 108
# etc.: 95
# no requirement: 73
# details shared: 66
# no response: 56
# requirement: 46
# call back: 18
# duplicate lead: 8
# quote send: 5
# budget issue: 4
# december 2022: 3
# already touch with customers: 3
# assigned to partner. intial meeting done. will convert to opp post complete info: 3
# fu under progress: 2
# not lifted: 2
# less then 6 months: 2
# more then 3 months: 2
# not reachable: 2
# price shared: 2
# less than 5 months: 2
# october 2022: 2
# low budget: 2
# november 2022: 2
# fu under progress.: 2
# uttarpradesh state lead: 1
# drop, now not intrested: 1
# quotation shared with him for idb. he dont have enough fund as of now. he is just evaluating options.: 1
# called to know the price of idb: 1
# quotation shared for ultra stretch and 49vl5g. he will check with management and update us: 1
# quote shared with him and he will update us after demo: 1
# update- as per customer no enquiry was made.: 1
# quote shared for 86 inch. he is evaluation local brand of trueview: 1
# call not connecting: 1
# update---27th aug--customer has to come for product demo: 1
# reseller want to have gem authorization.: 1
# he is looking for interactive display. quote shared with him.: 1
# exiting customer: 1
# kinnari eletronis vatwa has bid for the same. and they are going to purchase from them.: 1
# already in touch with him since long. he has not finalized yet. lead forwarded to rd: 1
# customer budget is 1.25+tax for 75 inch idb. i have given our no regret offer and also explained why lg is better and premium. he said he will come back in a day or two.: 1
# drop, wrong number: 1
# connecting for issue: 1
# discussed with the client they purchased 65um3df from the channel. unable to track the supplier. hence closing in the system. mail sent to client for our display range.: 1
# tried contact him but couldn't able to connect. lead forwarded to rd: 1
# known partner and already working on a case. only cross checking prices hence dropping.: 1
# dropped.. have purchased cloudwalker: 1
# couldnt connect: 1
# quotation sent – 75tr3dj , work in progress, he will buy after 2 months. he has not even seen the quote yet.: 1
# drop, still no plan for purchase: 1
# customer phone is gets switched off: 1
# known partner and we have installed 3 video walls pan india for cctv. we supplied 49vl5b at rs. 62000 and then again 49vl5f at rs. 71000.now the available model is 49vl5g at 80000 + which partner is rechecking and hence made inquiry.closing the inquiry si: 1
# purchase vu brand: 1
# custome purchase  consumer product: 1
# delhi enquirey: 1
# budget problem.: 1
# customer purchase benq for price differance: 1
# customer want product t 15000: 1
# mobile is switched off. tried 3 times: 1
# he want 98 inch in below 2 lacs: 1
# phone swtiched off: 1
# he want 65 inch at 50k: 1
# custome has not receive call. as on 31st may- spoke with customer, he will come for demo in next week.14-06-2022: 1
# quote shared with customer, he will confirm after 2 months. lead shared with partner.: 1
# purchased viewsonic panel: 1
# didn't pickup the call: 1
# he is comparing with senses which is local brand.: 1
# client was inquiring for prices. already quoted by few partners. they even purchased as per recent update but client has not confiermed partner name.: 1
# repeat enquiry: 1
# response: 1
# demo to be planned: 1
# need to do domestic trade biz: 1
# he is requesting demo in aligarh-up, plz share to up person.: 1
# he is looking for consumer product for home: 1
# asked to contact him after 8th jan.: 1
# we have pitched 110 inch fu under prgress: 1
# forwarded to aurangabad rd for further process: 1
# already working on idb will create opp post clarfying on signage: 1
# he is an event organization and looking for rental displays. hence dropping in system.: 1
# customer getting price from jaipur which low than our operating price.: 1
# client is cross checking on prices. its a rc case of subway and the franchisee is trying to get pricing from elsewhere.: 1
# update--14th sept--customer will discuss in detail tomorrow: 1
# already connect with partner: 1
# not picking calls, called many times: 1
# communication number not available.: 1
# update--4th aug--customer visiting experience centre on 8th sept: 1
# need for home segment. they purchased vu 85 inch tv for their home: 1
# one month: 1
# dont have budget. he want dot led: 1
# we are not going to match technical specification: 1
# looking for not made in china active outdoor led for government project: 1
# 4/8 months: 1
# 9 months - 1 year: 1
# 14:00~15:00: 1
# november 22: 1
# drop, not intrested: 1
# he is in discussion internally and will update.: 1
# drop, lookong for consumer product: 1
# última revisión: 26/07/21: 1
# 25-nov-2021  no mobile number, sent a mail to customer: 1
# customer has been not  answering call: 1
# call not picking: 1
# want to do trade product business: 1
# phone number not available: 1
# purchased some local panel, budget issue: 1
# he has asked to connect next week. he want to see the physical demo.: 1
# existing case worked by our disti, crew business, hence closing as client is only checking for commercials: 1
# drop, already done with partner: 1
# mayur electronic connect with client: 1
# spoke with shubham who is student. he said he will speak with his sir and revert back after 2 weeks.: 1
# 45 days: 1
# discussion to be done with customer: 1
# already purchase with rd: 1
# september 2022: 1
# we are already in touch with this cutsomer from last 2 years, he has never purchased any product till date. i called him up twice but no reponse.: 1
# existing partner, discussed and addressed the concern. the partner had taken pricing and wanted to re-check as the model quoted is changed.: 1
# discussed with client, they were just evaluating the product, they have no plans to buy the same, hence closing in the system.: 1
# we were already working here, we are facing challenge as we dont have 49vl5g in stock. order lost in march due to unavailabilty of 49vl5g.: 1
# quote shared with customer. he will revert with an update: 1
# update-- 4th aug--detailed discussion to be done on 6th aug: 1
# discussed with client. they need 24 inch display for digital signage. mentioned for our available sizes, he shall revert.: 1
# the rerquirement is for pune. emailed client looping pune team to meet and visit the client.: 1
# project cancle: 1
# want to take retail monitor: 1
# budget problem: 1
# conference/meeting room/collaboration spaces: 1
# looking for home use: 1
# already in touch with partner.: 1
# meeting date to be finalised: 1
# update- 4th aug- customer asked to call on monday: 1
# he want demo in sangli, i have looped with local partner.: 1
# update- call to be made on tuesday: 1
# he want physical demo of tr3bf in nashik. but there budget is also very low. so first he will discuss with management on budget then confirm back for demo: 1
# converted this lead into opportunity.: 1
# discussed with client they need for csr activity. prices expectation is very much low.: 1
# demo scheduled for 24th oct: 1
# discussed with client. we need to align demo. the expectation is connecting apple devices but not mandatory. once demo is done, we shall update: 1
# discussed with client. will plan for demo.: 1
# need to arrange quote and demo.: 1
# quote sent to customer.: 1
# under discussion: 1
# remarks : customer looking for 65 inches and 75 inches  each 1 qty: 1
# meeting planned for further discussion: 1
# customer will come for demo in next week, than he will decide further: 1
# he want demo next week: 1
# call and discused to custome customer wants demo.: 1
# demo planned, will update further status once its completed: 1
# quote shared with customer, lead shared with partner to take it further.: 1
# will come for the demo: 1
# quote send meeting pending: 1
# (select id_timeline): 1
# demo aligned for client: 1
# demo completed, customer asked to come feb 10th for closure.: 1
# call after 3 june: 1
# he want demo next month at pune - 15 may: 1
# order taken: 1
# discussed with client. demo aligned. once done, will update.: 1
# proposal submitted , due to covid md is not comin to office for the meeting.: 1
# purchase planning after 3 months: 1
# quotation shared in communication: 1
# is an interior designer. working on turnkey projects. mr bhuvnesh is in contact and shared specs and prices.: 1
# budget low hence client have not went ahead.: 1
# quote has been sent to customer.: 1
# already close in july purchse with rd: 1
# update- 7th aug--demo given. customer will confirm next week: 1
# tried to reach him multipe times from last 7 days but couldn't get through: 1
# discused with ankit in dehli: 1
# demo to be aligned: 1
# il220100042906 - repeat inquiry hence closing this in system.: 1
# partner is already in touch with our rd, orno. the partner needs to cross check on the information as the size is changed from 49 to 50 now. closing the opprtunity as its existing with rd.: 1
# scheduling a meeting: 1
# already shared quotation through si.: 1
# quotation shared.: 1
# invalid lead: 1
# discussed with the client, tr3bg & one quick works demo scheduled on 27th july 2022.post demo they will decide on procuring the unit.: 1
# demo scheduled for first week feb: 1
# the client budget is within 1 lacs they need 55 inch aio solution. as per discussion, they are comparing with jabra and we proposed to check if they need only displays. but due to budget contraint, they are dropping the idea.: 1
# the partner is checking price for an ongoing case of barc. we have discussed on new case with the partner.its useful to take our discussion further for new inquries.closing the opportunity in system as of now as its made only for cross checking prices.: 1
# spoke with custome he want 43" tv: 1
# don’t have budget: 1
# client shall get back for exploring demo of idb, post that they will decide on procuring the same.: 1
# already in discussion with partner from bangalore (kohinoor) and with mr. indraneel from corporate office: 1
# reuired for office. asked to share quotation: 1
# size not available: 1
# need to discuss with client in next two months. they need to check the product and accridngly proceed for personal use.: 1
# spoken to client, he will check if they need demo and confirm: 1
# they are consultant and i am already in touch with customer.: 1
# demo done: 1
# idb detais send: 1
# get back in 1 wk: 1
# customer is looking for residential 43 inch display for home use: 1
# meeting planned nextweek.: 1
# dropped. contact no not valid: 1
# needs hotel tv after 4 months, will call us.: 1
# treid many times but phone not reachable: 1
# couldn't conect: 1
# need to call on friday 27th: 1
# discussed with client. they have no budgets for purchase for now, they wont buy hence closing in the system.: 1
# already in touch with there team: 1
# lead belongs to maharashtra: 1
# due to budget issue, customer has bought maxhub panel.: 1
# next week he will come for demo at lg office: 1
# his budget is under 50k only: 1
# its bihar customer: 1
# connected with partner for studio setup with camera: 1
# quote shared but there budget is very low: 1
# tried to reach him multiple times, but couldn't get thru.: 1
# drop no plan for purchase: 1
# budget issue.: 1
# customer need shortthrow projector: 1
# rajnikant is working in this case ho in ahmedabad and its under process.: 1
# quotation shared with customer: 1
# connect with partner: 1
# not reachable, i had shared lead with partner: 1
# no drop this lead, no budget!: 1
# purchased from binary @ 1.23l: 1
# looking for outdoor display. cusotmer has no clarity on the solution. email shared for understanding and waiting for reply: 1
# discussed with client. they are not evaluatuating idb as of now, they have no plans to buy hence closing in the system.: 1
# discussed with the client. they are interersted in our tr3dj series demo planned for 29th june post they will plan on procurement. will keep update.: 1
# detail shared with him on email. he is looking for one unit of 65 inch for his conference room: 1
# already in touch with customer: 1
# mr rajnikant is allign with the client.: 1
# discussed with client, quote sent.: 1
# he is looking for an interactive display. discussed with client, will update as the case progress.: 1
# we are already in touch with customer thru partner: 1
# customer visit at uv business and see the demo within 2 to 3 days.: 1
# already in touch with customer from last 10 days. dropping it because we are already in touch: 1
# his budget is very low but we are trying to convince him for 65 inch: 1
# discussed with client.they are looking for aio solution with vc. they will call after 20th for the demo and then purchase through gem.: 1
# discussed with the client. prices shared for onequick and idb on mail. customer to confirm about demo of the sku and finalise on procurement.: 1
# 3 months: 1
# asked to call on 4th may: 1
# received po.: 1
# september: 1
# no contact number, i have dropped a email requesting for the same.: 1
# he is looking for display for his restaurant. he has asked to contact him after 1 month as restaurant work is under progress: 1
# his budget is very low.: 1
# looking for active led in a range of 5 lakhs . not a prospetive buyer: 1
# our partner, vis networks is working on this inquiry and client is cross-checking the prices. hence closing in the system.: 1
# not reachable , lead shared with partner: 1
# looking for air conditioners: 1
# withdrawn the decission to purchase: 1
# asked to call next week: 1
# quote shared with him.: 1

# %%
# 'expected_timeline' 열에서 값이 있는 행만 선택
df_valid_rows = df_train.dropna(subset=['expected_timeline'])

# 'expected_timeline' 열의 값을 모두 가져와서 텍스트로 결합
text_data = ' '.join(df_valid_rows['expected_timeline'].astype(str))

# 토큰화 (단어 분리)
tokens = word_tokenize(text_data)

# 단어 빈도수 계산
word_freq = Counter(tokens)

word_freq
# Out:
# Counter({'0-3m': 17326,
#          '3-6m': 5035,
#          '1y': 3028,
#          '9-12m': 1107,
#          '6-9m': 1102,
#          '.': 247,
#          'no': 143,
#          'months': 122,
#          'requirement': 119,
#          'less': 112,
#          'than': 112,
#          '6': 110,
#          'follow': 109,
#          'etc': 95,
#          'shared': 90,
#          'for': 69,
#          'to': 68,
#          'with': 67,
#          'details': 66,
#          'response': 57,
#          'the': 50,
#          ',': 49,
#          'is': 45,
#          'in': 42,
#          'he': 41,
#          'customer': 36,
#          'demo': 36,
#          'and': 34,
#          'call': 32,
#          'will': 31,
#          'client': 30,
#          'not': 28,
#          'partner': 25,
#          'on': 24,
#          'budget': 24,
#          'they': 24,
#          'already': 23,
#          'back': 23,
#          'quote': 19,
#          'lead': 19,
#          'discussed': 17,
#          'have': 16,
#          'as': 15,
#          'we': 15,
#          'update': 14,
#          'looking': 14,
#          'has': 13,
#          'him': 13,
#          'touch': 13,
#          'need': 13,
#          'are': 13,
#          'of': 13,
#          'want': 13,
#          'from': 11,
#          'but': 11,
#          'hence': 11,
#          'inch': 11,
#          'purchase': 11,
#          'after': 10,
#          '--': 9,
#          'next': 9,
#          'our': 9,
#          'meeting': 9,
#          'low': 9,
#          'product': 9,
#          'done': 9,
#          'under': 9,
#          'closing': 8,
#          'system': 8,
#          'issue': 8,
#          'a': 8,
#          'quotation': 8,
#          'duplicate': 8,
#          'discussion': 8,
#          'prices': 8,
#          '2022': 8,
#          'idb': 8,
#          'asked': 8,
#          '3': 8,
#          'purchased': 8,
#          'drop': 8,
#          'rd': 7,
#          'week': 7,
#          'price': 7,
#          'case': 7,
#          'come': 7,
#          'send': 7,
#          'at': 7,
#          'progress': 7,
#          'then': 7,
#          'display': 7,
#          'sent': 6,
#          'be': 6,
#          'this': 6,
#          'now': 6,
#          'its': 6,
#          'further': 6,
#          'post': 6,
#          'working': 6,
#          'contact': 6,
#          'i': 6,
#          'his': 6,
#          '2': 6,
#          'connect': 6,
#          'aug': 5,
#          'confirm': 5,
#          'times': 5,
#          "n't": 5,
#          'get': 5,
#          'check': 5,
#          '1': 5,
#          'only': 5,
#          'checking': 5,
#          'an': 5,
#          'made': 5,
#          'available': 5,
#          'very': 5,
#          'planned': 5,
#          'fu': 5,
#          'number': 5,
#          'reachable': 5,
#          'home': 5,
#          'update-': 4,
#          'tried': 4,
#          'days': 4,
#          'could': 4,
#          'cross': 4,
#          'due': 4,
#          'dropping': 4,
#          'custome': 4,
#          'same': 4,
#          'office': 4,
#          'plan': 4,
#          '65': 4,
#          '4th': 4,
#          'buy': 4,
#          'phone': 4,
#          'local': 4,
#          '49vl5g': 4,
#          'opp': 4,
#          'last': 3,
#          'through': 3,
#          'aligned': 3,
#          '-': 3,
#          'inquiry': 3,
#          'existing': 3,
#          'scheduled': 3,
#          'solution': 3,
#          'per': 3,
#          'take': 3,
#          'spoke': 3,
#          'tv': 3,
#          'shall': 3,
#          'decide': 3,
#          'discuss': 3,
#          'use': 3,
#          'one': 3,
#          'connecting': 3,
#          'once': 3,
#          'month': 3,
#          'pune': 3,
#          'there': 3,
#          'email': 3,
#          'business': 3,
#          'mail': 3,
#          'december': 3,
#          'november': 3,
#          'dropped': 3,
#          'led': 3,
#          '5': 3,
#          'us': 3,
#          'panel': 3,
#          'off': 3,
#          'which': 3,
#          'brand': 3,
#          'consumer': 3,
#          'customers': 3,
#          'forwarded': 3,
#          'called': 3,
#          'dont': 3,
#          'revert': 3,
#          'assigned': 3,
#          'intial': 3,
#          'convert': 3,
#          'complete': 3,
#          'info': 3,
#          'been': 2,
#          'july': 2,
#          'given': 2,
#          'reach': 2,
#          'discused': 2,
#          'repeat': 2,
#          'needs': 2,
#          'size': 2,
#          'changed': 2,
#          'si': 2,
#          'first': 2,
#          'feb': 2,
#          'within': 2,
#          'lacs': 2,
#          'aio': 2,
#          'comparing': 2,
#          'if': 2,
#          'displays': 2,
#          'new': 2,
#          'opportunity': 2,
#          'october': 2,
#          '43': 2,
#          't': 2,
#          'procuring': 2,
#          '(': 2,
#          ')': 2,
#          'share': 2,
#          'two': 2,
#          '27th': 2,
#          'unit': 2,
#          'mr': 2,
#          'communication': 2,
#          'expectation': 2,
#          ':': 2,
#          'inches': 2,
#          '75': 2,
#          'completed': 2,
#          'it': 2,
#          'june': 2,
#          'may': 2,
#          'order': 2,
#          'taken': 2,
#          'physical': 2,
#          'also': 2,
#          'management': 2,
#          'detail': 2,
#          'rajnikant': 2,
#          'interactive': 2,
#          'thru': 2,
#          'visit': 2,
#          'see': 2,
#          'trying': 2,
#          'gem': 2,
#          'procurement': 2,
#          'september': 2,
#          'requesting': 2,
#          'restaurant': 2,
#          'work': 2,
#          'active': 2,
#          'range': 2,
#          'plans': 2,
#          'outdoor': 2,
#          'many': 2,
#          'team': 2,
#          'lg': 2,
#          '50k': 2,
#          'lifted': 2,
#          'process': 2,
#          'had': 2,
#          'known': 2,
#          'even': 2,
#          'yet': 2,
#          'switched': 2,
#          'rs': 2,
#          'model': 2,
#          'vu': 2,
#          'problem': 2,
#          'mobile': 2,
#          'was': 2,
#          'quoted': 2,
#          'by': 2,
#          'enquiry': 2,
#          'more': 2,
#          'said': 2,
#          'intrested': 2,
#          'going': 2,
#          'just': 2,
#          'evaluating': 2,
#          'up': 2,
#          'do': 2,
#          'trade': 2,
#          'date': 2,
#          'pricing': 2,
#          'were': 2,
#          'signage': 2,
#          'project': 2,
#          'picking': 2,
#          '8th': 2,
#          'sept': 2,
#          'close': 1,
#          'purchse': 1,
#          '7th': 1,
#          'multipe': 1,
#          '7': 1,
#          'ankit': 1,
#          'dehli': 1,
#          'il220100042906': 1,
#          'orno': 1,
#          'information': 1,
#          '49': 1,
#          '50': 1,
#          'opprtunity': 1,
#          'scheduling': 1,
#          'went': 1,
#          'ahead': 1,
#          'invalid': 1,
#          '55': 1,
#          'jabra': 1,
#          'proposed': 1,
#          'contraint': 1,
#          'idea': 1,
#          'ongoing': 1,
#          'barc': 1,
#          'partner.its': 1,
#          'useful': 1,
#          'inquries.closing': 1,
#          "''": 1,
#          'don': 1,
#          '’': 1,
#          'exploring': 1,
#          'that': 1,
#          'bangalore': 1,
#          'kohinoor': 1,
#          'mr.': 1,
#          'indraneel': 1,
#          'corporate': 1,
#          'reuired': 1,
#          'accridngly': 1,
#          'proceed': 1,
#          'personal': 1,
#          'spoken': 1,
#          'tr3bg': 1,
#          '&': 1,
#          'quick': 1,
#          'works': 1,
#          '2022.post': 1,
#          'interior': 1,
#          'designer': 1,
#          'turnkey': 1,
#          'projects': 1,
#          'bhuvnesh': 1,
#          'specs': 1,
#          'planning': 1,
#          'converted': 1,
#          'into': 1,
#          'csr': 1,
#          'activity': 1,
#          'much': 1,
#          '24th': 1,
#          'oct': 1,
#          'align': 1,
#          'apple': 1,
#          'devices': 1,
#          'mandatory': 1,
#          'arrange': 1,
#          'remarks': 1,
#          'each': 1,
#          'qty': 1,
#          'wants': 1,
#          'status': 1,
#          'pending': 1,
#          'select': 1,
#          'id_timeline': 1,
#          '10th': 1,
#          'closure': 1,
#          '15': 1,
#          'proposal': 1,
#          'submitted': 1,
#          'covid': 1,
#          'md': 1,
#          'comin': 1,
#          'consultant': 1,
#          'am': 1,
#          'tr3bf': 1,
#          'nashik': 1,
#          'so': 1,
#          'wk': 1,
#          'conference': 1,
#          'room': 1,
#          'allign': 1,
#          'uv': 1,
#          '10': 1,
#          'because': 1,
#          'convince': 1,
#          'client.they': 1,
#          'vc': 1,
#          '20th': 1,
#          'onequick': 1,
#          'about': 1,
#          'sku': 1,
#          'finalise': 1,
#          'interersted': 1,
#          'tr3dj': 1,
#          'series': 1,
#          '29th': 1,
#          'keep': 1,
#          'received': 1,
#          'po': 1,
#          'lakhs': 1,
#          'prospetive': 1,
#          'buyer': 1,
#          'vis': 1,
#          'networks': 1,
#          'cross-checking': 1,
#          'air': 1,
#          'conditioners': 1,
#          'withdrawn': 1,
#          'decission': 1,
#          'evaluatuating': 1,
#          'cusotmer': 1,
#          'clarity': 1,
#          'understanding': 1,
#          'waiting': 1,
#          'reply': 1,
#          'binary': 1,
#          '@': 1,
#          '1.23l': 1,
#          'residential': 1,
#          'nextweek': 1,
#          'valid': 1,
#          'hotel': 1,
#          '4': 1,
#          'treid': 1,
#          'conect': 1,
#          'friday': 1,
#          'budgets': 1,
#          'wont': 1,
#          'belongs': 1,
#          'maharashtra': 1,
#          'bought': 1,
#          'maxhub': 1,
#          'bihar': 1,
#          'connected': 1,
#          'studio': 1,
#          'setup': 1,
#          'camera': 1,
#          'multiple': 1,
#          'sangli': 1,
#          'looped': 1,
#          'shortthrow': 1,
#          'projector': 1,
#          'ho': 1,
#          'ahmedabad': 1,
#          '!': 1,
#          'detais': 1,
#          'tuesday': 1,
#          'aug-': 1,
#          'monday': 1,
#          '..': 1,
#          'cloudwalker': 1,
#          'couldnt': 1,
#          '–': 1,
#          '75tr3dj': 1,
#          'seen': 1,
#          'still': 1,
#          'gets': 1,
#          'installed': 1,
#          'video': 1,
#          'walls': 1,
#          'pan': 1,
#          'india': 1,
#          'cctv': 1,
#          'supplied': 1,
#          '49vl5b': 1,
#          '62000': 1,
#          'again': 1,
#          '49vl5f': 1,
#          '71000.now': 1,
#          '80000': 1,
#          '+': 1,
#          'rechecking': 1,
#          'inquiry.closing': 1,
#          'delhi': 1,
#          'enquirey': 1,
#          'benq': 1,
#          'differance': 1,
#          '15000': 1,
#          '98': 1,
#          'below': 1,
#          'swtiched': 1,
#          'receive': 1,
#          '31st': 1,
#          'may-': 1,
#          'week.14-06-2022': 1,
#          'did': 1,
#          'pickup': 1,
#          'senses': 1,
#          'inquiring': 1,
#          'few': 1,
#          'partners': 1,
#          'recent': 1,
#          'confiermed': 1,
#          'name': 1,
#          'able': 1,
#          '65um3df': 1,
#          'channel': 1,
#          'unable': 1,
#          'track': 1,
#          'supplier': 1,
#          'uttarpradesh': 1,
#          'state': 1,
#          'ultra': 1,
#          'stretch': 1,
#          '-27th': 1,
#          'reseller': 1,
#          'authorization': 1,
#          '1.25+tax': 1,
#          'regret': 1,
#          'offer': 1,
#          'explained': 1,
#          'why': 1,
#          'better': 1,
#          'premium': 1,
#          'day': 1,
#          'or': 1,
#          'since': 1,
#          'long': 1,
#          'finalized': 1,
#          'exiting': 1,
#          'wrong': 1,
#          '86': 1,
#          'evaluation': 1,
#          'trueview': 1,
#          'kinnari': 1,
#          'eletronis': 1,
#          'vatwa': 1,
#          'bid': 1,
#          'them': 1,
#          'know': 1,
#          'enough': 1,
#          'fund': 1,
#          'options': 1,
#          'viewsonic': 1,
#          'aligarh-up': 1,
#          'plz': 1,
#          'person': 1,
#          'some': 1,
#          'worked': 1,
#          'disti': 1,
#          'crew': 1,
#          'commercials': 1,
#          'mayur': 1,
#          'electronic': 1,
#          'shubham': 1,
#          'who': 1,
#          'student': 1,
#          'speak': 1,
#          'sir': 1,
#          'weeks': 1,
#          '45': 1,
#          'domestic': 1,
#          'biz': 1,
#          'cutsomer': 1,
#          'years': 1,
#          'never': 1,
#          'any': 1,
#          'till': 1,
#          'twice': 1,
#          'reponse': 1,
#          'addressed': 1,
#          'concern': 1,
#          'wanted': 1,
#          're-check': 1,
#          'here': 1,
#          'facing': 1,
#          'challenge': 1,
#          'stock': 1,
#          'lost': 1,
#          'march': 1,
#          'unavailabilty': 1,
#          'detailed': 1,
#          '6th': 1,
#          '24': 1,
#          'digital': 1,
#          'mentioned': 1,
#          'sizes': 1,
#          'rerquirement': 1,
#          'emailed': 1,
#          'looping': 1,
#          'meet': 1,
#          'cancle': 1,
#          'retail': 1,
#          'monitor': 1,
#          'conference/meeting': 1,
#          'room/collaboration': 1,
#          'spaces': 1,
#          'finalised': 1,
#          'answering': 1,
#          'jan.': 1,
#          'pitched': 1,
#          '110': 1,
#          'prgress': 1,
#          'aurangabad': 1,
#          'create': 1,
#          'clarfying': 1,
#          'event': 1,
#          'organization': 1,
#          'rental': 1,
#          'getting': 1,
#          'jaipur': 1,
#          'operating': 1,
#          'rc': 1,
#          'subway': 1,
#          'franchisee': 1,
#          'elsewhere': 1,
#          '14th': 1,
#          'tomorrow': 1,
#          'calls': 1,
#          'visiting': 1,
#          'experience': 1,
#          'centre': 1,
#          'segment': 1,
#          '85': 1,
#          'their': 1,
#          'dot': 1,
#          'match': 1,
#          'technical': 1,
#          'specification': 1,
#          'china': 1,
#          'government': 1,
#          '4/8': 1,
#          '9': 1,
#          'year': 1,
#          '14:00~15:00': 1,
#          '22': 1,
#          'internally': 1,
#          'lookong': 1,
#          'última': 1,
#          'revisión': 1,
#          '26/07/21': 1,
#          '25-nov-2021': 1})

# %% [markdown]
# ## 2. 데이터 전처리

# %% [markdown]
# ### 레이블 인코딩

# %%
def label_encoding(series: pd.Series) -> pd.Series:
    """범주형 데이터를 시리즈 형태로 받아 숫자형 데이터로 변환합니다."""

    my_dict = {}

    # 모든 요소를 문자열로 변환
    series = series.astype(str)

    for idx, value in enumerate(sorted(series.unique())):
        my_dict[value] = idx
    series = series.map(my_dict)

    return series

# %%
# 레이블 인코딩할 칼럼들
label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_country.1",
    "customer_position",
    "response_corporate",
    "expected_timeline",
]

df_all = pd.concat([df_train[label_columns], df_test[label_columns]])

for col in label_columns:
    df_all[col] = label_encoding(df_all[col])

# %%
df_all

# %% [markdown]
# 다시 학습 데이터와 제출 데이터를 분리합니다.

# %%
for col in label_columns:  
    df_train[col] = df_all.iloc[: len(df_train)][col]
    df_test[col] = df_all.iloc[len(df_train) :][col]

# %%
df_train

# %%
df_test

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 모든 열에 대한 상자그림 플로팅
plt.figure(figsize=(20, 15))
sns.boxplot(data=df_train, orient="h")  # orient="h"는 가로 방향 상자그림을 의미합니다
plt.title('Boxplots for Outliers in All Columns')
plt.show()

# %%
print(df_train.describe())

# %%
# 각 열에 대한 기술 통계량 출력
print(df_train.describe())

# 각 열의 분포 시각화 (히스토그램, 상자 그림)
for column in df_train.columns:
    plt.figure(figsize=(5, 2))
    sns.histplot(df_train[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
# 각 열의 상관 관계 히트맵
correlation_matrix = df_train.corr()
plt.figure(figsize=(14, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# NaN 값 확인
nan_values = df_train.isnull().sum()
print("NaN Values:\n", nan_values)

df_train = df_train.fillna(0)

# %%
# 무한대 값 확인
inf_values = df_train[df_train == np.inf].sum()
print("Infinite Values:\n", inf_values)

# %% [markdown]
# 1. 결측값 처리
#
#
# 2. 표준편차가 큰 열 처리:
# 해결방안:
# 표준화 (Standardization) 또는 정규화 (Normalization): 데이터의 스케일을 맞춰주어 표준편차가 큰 열의 영향을 줄일 수 있습니다. 주로 Z-score 표준화나 Min-Max 정규화를 사용합니다.
#
#
#
# 3. 이진 변수의 클래스 불균형 처리:
# 해결방안:
# 클래스 가중치 설정: 클래스의 불균형이 큰 경우, 모델 학습 시 클래스에 가중치를 부여하여 균형을 맞출 수 있습니다.

# %%
import pandas as pd

# df_train은 데이터프레임 객체라고 가정합니다.
# 'expected_timeline' 열과 다른 열들 간의 상관 관계 확인
correlation_matrix = df_train.corrwith(df_train['expected_timeline'])

# 출력
print("상관 관계:")
print(correlation_matrix)

# %%
import pandas as pd
import numpy as np

# df_train은 데이터프레임 객체라고 가정합니다.
unique_values = df_train['expected_timeline'].unique()

# 최솟값과 최댓값 출력
min_value = np.min(unique_values)
max_value = np.max(unique_values)

print("최솟값:", min_value)
print("최댓값:", max_value)

# 각 숫자의 빈도 출력
value_counts = df_train['expected_timeline'].value_counts()
print("각 숫자의 빈도:")
print(value_counts)

# %% [markdown]
# ### 2-2. 학습, 검증 데이터 분리

# %%
x_train, x_val, y_train, y_val = train_test_split(
    df_train.drop("is_converted", axis=1),
    df_train["is_converted"],
    test_size=0.2,
    shuffle=True,
    random_state=400,
)

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %%
model = DecisionTreeClassifier()

# %% [markdown]
# ### 모델 학습

# %%
model.fit(x_train.fillna(0), y_train)

# %% [markdown]
# ### 모델 성능 보기

# %%
def get_clf_eval(y_test, y_pred=None):
    confusion = confusion_matrix(y_test, y_pred, labels=[True, False])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, labels=[True, False])
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred, labels=[True, False])

    print("오차행렬:\n", confusion)
    print("\n정확도: {:.4f}".format(accuracy))
    print("정밀도: {:.4f}".format(precision))
    print("재현율: {:.4f}".format(recall))
    print("F1: {:.4f}".format(F1))

# %%
pred = model.predict(x_val.fillna(0))
get_clf_eval(y_val, pred)

# %% [markdown]
# ## 4. 제출하기

# %% [markdown]
# ### 테스트 데이터 예측

# %%
# 예측에 필요한 데이터 분리
x_test = df_test.drop(["is_converted", "id"], axis=1)

# %%
test_pred = model.predict(x_test.fillna(0))
sum(test_pred) # True로 예측된 개수

# %% [markdown]
# ### 제출 파일 작성

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["is_converted"] = test_pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %% [markdown]
# **우측 상단의 제출 버튼을 클릭해 결과를 확인하세요**
